# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelFigueroa02/MCPI_Student_Repo/blob/main/courses/1-Semester/fundamentals%20of%20statistics/Projects/Estad%C3%ADstica_Descriptiva_Visualizaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
#   <img src="https://raw.githubusercontent.com/MiguelFigueroa02/MCPI_Student_Repo/refs/heads/main/images/logo.png"
#        width="30%">
# </p>
#
# #Fundamentos de Estadística
# ---
# **Profesor:** Dr. Daniel de La Rosa Gómez\
# **Estudiante:** Miguel Figueroa Aguilar

# %% [markdown]
# ## Estadística Descriptiva
# ---
# Nombre y Fuente:\
# En este caso elegí el Dataset relacionado con la hipertensión Arterial en México a partir de la plataforma de [Kaggle](https://www.kaggle.com/datasets/frederickfelix/hipertensin-arterial-mxico)\
# Este es un conglomerado a partir de información de salud de pacientes reunidos a partir de la información de la Encuesta Nacional de Salud y Nutrición, en donde se reune información de diferentes tipo de información biométrica que se irá explicando a detalle posteriormente para identificar riesgos de hipertensión.\
# \
# ¿Qué representan los datos?\
